# %%
import pandas as pd

pd.set_option('display.max_columns', None)

database = pd.read_csv('C://Users//eduar//Desktop//DEV//Football//PremierLeague//database.csv',index_col=None)

# %%
# Agrupar os dados por jogador e calcular a soma dos chutes ao gol e a contagem de aparições
db_agrupado_jogador = database.groupby(['Jogador','Time'], as_index= False).agg(
    Total_Gols=('Gols','sum'),
    Total_Chutes=('TC', 'sum'),   # Soma dos chutes ao gol
    Aparicoes=('Jogador', 'count'), # Contagem de aparições
    Total_Chutes_Gol=('CaG', 'sum') # Contagem de aparições
)

# %%
db_agrupado_jogador['Média_chute']=round(db_agrupado_jogador['Total_Chutes'] / db_agrupado_jogador['Aparicoes'],2)
db_agrupado_jogador['Média_chute_Gol']=round(db_agrupado_jogador['Total_Chutes_Gol'] / db_agrupado_jogador['Aparicoes'],2)
db_agrupado_jogador['Média_gol']=round(db_agrupado_jogador['Total_Gols'] / db_agrupado_jogador['Aparicoes'],2)
db_agrupado_jogador['Taxa_Chutes_Gol'] = db_agrupado_jogador['Total_Chutes_Gol'] / db_agrupado_jogador['Total_Chutes']

# %%
database[database['Jogador'].isin(['','Noni Madueke'])]
# Out:
#               Jogador     Time   # Nação Pos.   Idade  Min.  Gols  Assis.  PB  \
# 249   Nicolas Jackson  Chelsea  15   SEN   FW  23-059    66     0       0   0
# 572   Nicolas Jackson  Chelsea  15   SEN   FW  23-066    67     1       1   0
# 576      Noni Madueke  Chelsea  11   ENG   RW  22-168    90     3       0   0
# 863   Nicolas Jackson  Chelsea  15   SEN   FW  23-073    90     1       0   0
# 866      Noni Madueke  Chelsea  11   ENG   RW  22-175    85     0       0   0
# 1156  Nicolas Jackson  Chelsea  15   SEN   FW  23-086    78     0       0   0
# 1160     Noni Madueke  Chelsea  11   ENG   RW  22-188    61     0       0   0
# 1247  Nicolas Jackson  Chelsea  15   SEN   FW  23-093    63     2       1   0
# 1251     Noni Madueke  Chelsea  11   ENG   RW  22-195    90     0       0   0
# 1564  Nicolas Jackson  Chelsea  15   SEN   FW  23-100    78     0       1   0
# 1568     Noni Madueke  Chelsea  11   ENG   RW  22-202    62     0       0   0
#
#       PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  Bloqueios   xG  npxG  \
# 249    0   1    1      0     0        21    0     0          0  0.5   0.5
# 572    0   1    1      0     0        33    0     0          1  0.2   0.2
# 576    0   6    5      0     0        32    1     0          0  0.6   0.6
# 863    0   4    3      1     0        17    0     0          0  1.6   1.6
# 866    0   3    1      0     0        37    2     0          1  0.5   0.5
# 1156   0   3    1      1     0        26    0     0          1  0.3   0.3
# 1160   0   3    0      0     0        26    0     1          0  0.1   0.1
# 1247   0   4    2      0     0        28    0     1          0  0.8   0.8
# 1251   0   2    1      0     0        32    0     1          0  0.2   0.2
# 1564   0   5    1      0     0        25    0     0          3  1.4   1.4
# 1568   0   1    0      0     0        23    2     0          0  0.2   0.2
#
#       xAG  SCA  GCA  Cmp  Att  Cmp%  PrgP  Conduções  PrgC  Tent  Suc  \
# 249   0.2    3    0   11   16  68,8     2         10     0     0    0
# 572   0.1    3    2   18   21  85,7     2         22     0     1    0
# 576   0.4    3    1   16   21  76,2     1         29     5     0    0
# 863   0.0    1    0    3    5  60,0     0         10     3     4    2
# 866   0.0    2    1   24   27  88,9     5         19     5     4    2
# 1156  0.0    0    0   11   14  78,6     2         15     1     1    0
# 1160  0.0    1    0   14   19  73,7     0         16     2     4    3
# 1247  0.4    3    2   14   17  82,4     2         22     5     2    0
# 1251  0.0    2    0   17   21  81,0     0         19     6     0    0
# 1564  0.2    2    1    7   14  50,0     0         10     3     2    1
# 1568  0.0    2    1    5   11  45,5     1         11     2     4    1
#
#             Data
# 249   2024-08-18
# 572   2024-08-25
# 576   2024-08-25
# 863   2024-09-01
# 866   2024-09-01
# 1156  2024-09-14
# 1160  2024-09-14
# 1247  2024-09-21
# 1251  2024-09-21
# 1564  2024-09-28
# 1568  2024-09-28

# %%
db_agrupado_jogador[db_agrupado_jogador['Jogador'].isin(['Matheus Cunha','Ollie Watkins'])]
# Out:
#            Jogador                     Time  Total_Gols  Total_Chutes  \
# 285  Matheus Cunha  Wolverhampton Wanderers           2            16
# 330  Ollie Watkins              Aston Villa           4            14
#
#      Aparicoes  Total_Chutes_Gol  Média_chute  Média_chute_Gol  Média_gol  \
# 285          6                 7         2.67             1.17       0.33
# 330          6                 7         2.33             1.17       0.67
#
#      Taxa_Chutes_Gol
# 285           0.4375
# 330           0.5000

# %%
db_agrupado_jogador[(db_agrupado_jogador['Time'].isin(['Liverpool','Arsenal','Manchester City']) & (db_agrupado_jogador['Aparicoes']>4))].sort_values(by='Média_chute_Gol', 
ascending=False, ignore_index= True).head(20)
# Out:
#                 Jogador             Time  Total_Gols  Total_Chutes  Aparicoes  \
# 0        Erling Haaland  Manchester City          10            30          6
# 1         Mohamed Salah        Liverpool           4            19          6
# 2           Bukayo Saka          Arsenal           1            18          6
# 3           Kai Havertz          Arsenal           3            18          6
# 4             Luis Díaz        Liverpool           5            14          6
# 5     Gabriel Magalhães          Arsenal           2             8          6
# 6        Joško Gvardiol  Manchester City           1             7          6
# 7      Leandro Trossard          Arsenal           2            10          6
# 8    Gabriel Martinelli          Arsenal           1             6          6
# 9        Bernardo Silva  Manchester City           0             9          6
# 10          Declan Rice          Arsenal           0             6          5
# 11           Diogo Jota        Liverpool           1            11          5
# 12                Sávio  Manchester City           0             7          5
# 13     Ryan Gravenberch        Liverpool           0             2          6
# 14     Andrew Robertson        Liverpool           0             3          6
# 15      Ibrahima Konaté        Liverpool           1             5          6
# 16  Alexis Mac Allister        Liverpool           0             4          6
# 17          Jeremy Doku  Manchester City           0             5          5
# 18       İlkay Gündoğan  Manchester City           0             6          5
# 19        Jack Grealish  Manchester City           0             6          5
#
#     Total_Chutes_Gol  Média_chute  Média_chute_Gol  Média_gol  Taxa_Chutes_Gol
# 0                 20         5.00             3.33       1.67         0.666667
# 1                 12         3.17             2.00       0.67         0.631579
# 2                  9         3.00             1.50       0.17         0.500000
# 3                  8         3.00             1.33       0.50         0.444444
# 4                  8         2.33             1.33       0.83         0.571429
# 5                  4         1.33             0.67       0.33         0.500000
# 6                  4         1.17             0.67       0.17         0.571429
# 7                  4         1.67             0.67       0.33         0.400000
# 8                  3         1.00             0.50       0.17         0.500000
# 9                  3         1.50             0.50       0.00         0.333333
# 10                 2         1.20             0.40       0.00         0.333333
# 11                 2         2.20             0.40       0.20         0.181818
# 12                 2         1.40             0.40       0.00         0.285714
# 13                 2         0.33             0.33       0.00         1.000000
# 14                 2         0.50             0.33       0.00         0.666667
# 15                 2         0.83             0.33       0.17         0.400000
# 16                 2         0.67             0.33       0.00         0.500000
# 17                 1         1.00             0.20       0.00         0.200000
# 18                 1         1.20             0.20       0.00         0.166667
# 19                 1         1.20             0.20       0.00         0.166667

# %% [markdown]
# ## Agrupado Time

# %%
sorted(database.Time.unique().tolist())
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton & Hove Albion',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Ipswich Town',
#  'Leicester City',
#  'Liverpool',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Nottingham Forest',
#  'Southampton',
#  'Tottenham Hotspur',
#  'West Ham United',
#  'Wolverhampton Wanderers']

# %%
db_agrupado_time = database.groupby(['Time'], as_index=False).agg(
    Total_Gols=('Gols', 'sum'),
    Total_Chutes=('TC', 'sum'),   # Soma dos chutes ao gol
    Aparicoes=('Data', 'nunique'), # Contagem de jogos únicos (datas únicas)
    Total_Chutes_Gol=('CaG', 'sum') # Soma dos chutes ao gol
)

# %%
db_agrupado_time['Média_chute']=round(db_agrupado_time['Total_Chutes'] / db_agrupado_time['Aparicoes'],2)
db_agrupado_time['Média_chute_gol']=round(db_agrupado_time['Total_Chutes_Gol'] / db_agrupado_time['Aparicoes'],2)
db_agrupado_time['Média_gol']=round(db_agrupado_time['Total_Gols'] / db_agrupado_time['Aparicoes'],2)
db_agrupado_time['Taxa_Chutes_Gol'] = db_agrupado_time['Total_Chutes_Gol'] / db_agrupado_time['Total_Chutes']

# %%
db_agrupado_time[db_agrupado_time['Time'].isin(['Chelsea','West Ham United'])].sort_values(by='Total_Chutes', ascending=False, ignore_index= True)
# Out:
#               Time  Total_Gols  Total_Chutes  Aparicoes  Total_Chutes_Gol  \
# 0  West Ham United           4            52          4                10
# 1          Chelsea           8            47          4                21
#
#    Média_chute  Média_chute_gol  Média_gol  Taxa_Chutes_Gol
# 0        13.00             2.50        1.0         0.192308
# 1        11.75             5.25        2.0         0.446809

# %%
db_agrupado_time.sort_values(by='Média_chute_gol', ascending=False, ignore_index= True)
# Out:
#                        Time  Total_Gols  Total_Chutes  Aparicoes  \
# 0         Tottenham Hotspur           5            63          4
# 1         Nottingham Forest           4            58          4
# 2           Manchester City          11            65          4
# 3                   Arsenal           6            45          4
# 4         Manchester United           5            53          4
# 5               Bournemouth           5            64          4
# 6                   Chelsea           8            47          4
# 7                 Liverpool           7            62          4
# 8                 Brentford           6            45          4
# 9    Brighton & Hove Albion           6            67          4
# 10              Aston Villa           7            53          4
# 11                   Fulham           4            58          4
# 12         Newcastle United           6            40          4
# 13           Leicester City           5            35          4
# 14           Crystal Palace           3            56          4
# 15  Wolverhampton Wanderers           4            44          4
# 16                  Everton           4            43          4
# 17              Southampton           1            47          4
# 18          West Ham United           4            52          4
# 19             Ipswich Town           2            25          4
#
#     Total_Chutes_Gol  Média_chute  Média_chute_gol  Média_gol  Taxa_Chutes_Gol
# 0                 24        15.75             6.00       1.25         0.380952
# 1                 24        14.50             6.00       1.00         0.413793
# 2                 24        16.25             6.00       2.75         0.369231
# 3                 21        11.25             5.25       1.50         0.466667
# 4                 21        13.25             5.25       1.25         0.396226
# 5                 21        16.00             5.25       1.25         0.328125
# 6                 21        11.75             5.25       2.00         0.446809
# 7                 21        15.50             5.25       1.75         0.338710
# 8                 19        11.25             4.75       1.50         0.422222
# 9                 19        16.75             4.75       1.50         0.283582
# 10                18        13.25             4.50       1.75         0.339623
# 11                17        14.50             4.25       1.00         0.293103
# 12                15        10.00             3.75       1.50         0.375000
# 13                14         8.75             3.50       1.25         0.400000
# 14                14        14.00             3.50       0.75         0.250000
# 15                14        11.00             3.50       1.00         0.318182
# 16                12        10.75             3.00       1.00         0.279070
# 17                12        11.75             3.00       0.25         0.255319
# 18                10        13.00             2.50       1.00         0.192308
# 19                 8         6.25             2.00       0.50         0.320000

# %% [markdown]
# ## Agrupado por Data

# %%
db_desempenho_por_data = database.groupby(['Time', 'Data'], as_index=False).agg(
    Total_Gols=('Gols', 'sum'),          # Soma de gols por data
    Total_Chutes=('TC', 'sum'),          # Soma de chutes por data
    Total_Chutes_Gol=('CaG', 'sum')      # Soma dos chutes ao gol por data
).sort_values(by=['Time', 'Data'])

# %%
db_desempenho_por_data['Taxa_Chutes'] = round(db_desempenho_por_data['Total_Gols'] / db_desempenho_por_data['Total_Chutes'],4)
db_desempenho_por_data['Taxa_Chutes_Gol'] = round(db_desempenho_por_data['Total_Gols'] / db_desempenho_por_data['Total_Chutes_Gol'],4)

# %%
db_desempenho_por_data[db_desempenho_por_data['Time'].isin(['Chelsea','West Ham United'])].tail(10)
# Out:
#                Time        Data  Total_Gols  Total_Chutes  Total_Chutes_Gol  \
# 20          Chelsea  2024-08-18           0            10                 3
# 21          Chelsea  2024-08-25           6            14                 8
# 22          Chelsea  2024-09-01           1            13                 7
# 23          Chelsea  2024-09-14           1            10                 3
# 72  West Ham United  2024-08-17           1            13                 2
# 73  West Ham United  2024-08-24           2            18                 3
# 74  West Ham United  2024-08-31           0            10                 2
# 75  West Ham United  2024-09-14           1            11                 3
#
#     Taxa_Chutes  Taxa_Chutes_Gol
# 20       0.0000           0.0000
# 21       0.4286           0.7500
# 22       0.0769           0.1429
# 23       0.1000           0.3333
# 72       0.0769           0.5000
# 73       0.1111           0.6667
# 74       0.0000           0.0000
# 75       0.0909           0.3333
